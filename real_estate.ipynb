# %% [markdown]
# ### Data Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("usa_housing_kaggle.csv")

# %%
data.head(5)
# Out:
#     Price  Bedrooms  Bathrooms  SquareFeet  YearBuilt  GarageSpaces  LotSize  \
# 0  221958         1        1.9        4827       1979             2     1.45
# 1  771155         2        2.0        1035       1987             2     1.75
# 2  231932         1        3.0        2769       1982             1     1.46
# 3  465838         3        3.3        2708       1907             3     1.62
# 4  359178         4        3.4        1175       1994             2     0.74
#
#    ZipCode  CrimeRate  SchoolRating
# 0    82240      48.60             5
# 1    74315      92.03             9
# 2    79249      52.08             3
# 3    80587      61.65             1
# 4    20756      15.66             4

# %%
rows, columns = data.shape
print("The total number of rows",rows)
print("The total number of columns",columns)
# Out:
# The total number of rows 300
# The total number of columns 10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Price         300 non-null    int64
#  1   Bedrooms      300 non-null    int64
#  2   Bathrooms     300 non-null    float64
#  3   SquareFeet    300 non-null    int64
#  4   YearBuilt     300 non-null    int64
#  5   GarageSpaces  300 non-null    int64
#  6   LotSize       300 non-null    float64
#  7   ZipCode       300 non-null    int64
#  8   CrimeRate     300 non-null    float64
#  9   SchoolRating  300 non-null    int64
# dtypes: float64(3), int64(7)
# memory usage: 23.6 KB

# %%
data.describe()
# Out:
#                Price    Bedrooms   Bathrooms  SquareFeet    YearBuilt  \
# count     300.000000  300.000000  300.000000   300.00000   300.000000
# mean   522761.916667    2.966667    2.464000  3052.75000  1962.616667
# std    256922.348275    1.451175    0.886184  1194.97144    36.005431
# min    112666.000000    1.000000    1.000000   840.00000  1902.000000
# 25%    299936.500000    2.000000    1.700000  2053.50000  1931.750000
# 50%    505806.500000    3.000000    2.400000  3127.00000  1961.000000
# 75%    744603.750000    4.000000    3.200000  4081.00000  1994.000000
# max    999684.000000    5.000000    4.000000  4997.00000  2022.000000
#
#        GarageSpaces     LotSize       ZipCode   CrimeRate  SchoolRating
# count    300.000000  300.000000    300.000000  300.000000    300.000000
# mean       1.513333    1.062200  54324.770000   49.324033      5.096667
# std        1.116832    0.543896  24718.938552   28.833220      2.674165
# ...

# %%
data.isna().sum()
# Out:
# Price           0
# Bedrooms        0
# Bathrooms       0
# SquareFeet      0
# YearBuilt       0
# GarageSpaces    0
# LotSize         0
# ZipCode         0
# CrimeRate       0
# SchoolRating    0
# dtype: int64

# %%
data.drop(columns=["ZipCode","GarageSpaces"],inplace=True)

# %%
data.head()
# Out:
#     Price  Bedrooms  Bathrooms  SquareFeet  YearBuilt  LotSize  CrimeRate  \
# 0  221958         1        1.9        4827       1979     1.45      48.60
# 1  771155         2        2.0        1035       1987     1.75      92.03
# 2  231932         1        3.0        2769       1982     1.46      52.08
# 3  465838         3        3.3        2708       1907     1.62      61.65
# 4  359178         4        3.4        1175       1994     0.74      15.66
#
#    SchoolRating
# 0             5
# 1             9
# 2             3
# 3             1
# 4             4

# %%
rows, columns = data.shape
print("The total number of rows",rows)
print("The total number of columns",columns)
# Out:
# The total number of rows 300
# The total number of columns 8

# %%
data.isna() ### True/False Value
data.isna().sum() ### Total count of each column
data.isna().sum().sum() ### Overall Total Count
# Out:
# 0

# %%
data.dropna(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates(inplace=True)

# %%
data["LotSize"].value_counts()
# Out:
# LotSize
# 1.75    9
# 1.46    5
# 0.44    5
# 0.96    5
# 1.63    4
#        ..
# 0.94    1
# 1.16    1
# 1.47    1
# 1.99    1
# 0.71    1
# Name: count, Length: 154, dtype: int64

# %%
data["SchoolRating"].value_counts()
# Out:
# SchoolRating
# 9    44
# 3    43
# 1    34
# 8    34
# 4    31
# 5    30
# 6    29
# 7    28
# 2    27
# Name: count, dtype: int64

# %%
data["SchoolRating"].value_counts().sort_values(ascending=True)
# Out:
# SchoolRating
# 2    27
# 7    28
# 6    29
# 5    30
# 4    31
# 1    34
# 8    34
# 3    43
# 9    44
# Name: count, dtype: int64

# %%
data["SchoolRating"].value_counts().sort_values(ascending=True).head(5).plot(kind="bar")
# Out:
# <Axes: xlabel='SchoolRating'>

# %%
data["SchoolRating"].value_counts().sort_values(ascending=False).head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='SchoolRating'>

# %%
data.head(5)
# Out:
#     Price  Bedrooms  Bathrooms  SquareFeet  YearBuilt  LotSize  CrimeRate  \
# 0  221958         1        1.9        4827       1979     1.45      48.60
# 1  771155         2        2.0        1035       1987     1.75      92.03
# 2  231932         1        3.0        2769       1982     1.46      52.08
# 3  465838         3        3.3        2708       1907     1.62      61.65
# 4  359178         4        3.4        1175       1994     0.74      15.66
#
#    SchoolRating
# 0             5
# 1             9
# 2             3
# 3             1
# 4             4

# %%
X = data[["Bedrooms","Bathrooms","SquareFeet"]]

# %%
y = data[["Price"]]

# %%
X
# Out:
#      Bedrooms  Bathrooms  SquareFeet
# 0           1        1.9        4827
# 1           2        2.0        1035
# 2           1        3.0        2769
# 3           3        3.3        2708
# 4           4        3.4        1175
# ..        ...        ...         ...
# 295         4        2.8        1129
# 296         3        2.4        4440
# 297         2        2.2        4694
# 298         5        2.0        4907
# 299         5        3.8        2141
#
# [300 rows x 3 columns]

# %%
y
# Out:
#       Price
# 0    221958
# 1    771155
# 2    231932
# 3    465838
# 4    359178
# ..      ...
# 295  862002
# 296  242483
# 297  758271
# 298  314835
# 299  501896
#
# [300 rows x 1 columns]

# %%
X.columns
# Out:
# Index(['Bedrooms', 'Bathrooms', 'SquareFeet'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train
# Out:
#      Bedrooms  Bathrooms  SquareFeet
# 92          3        3.8        3735
# 220         1        2.6        4833
# 251         2        1.5        3481
# 150         5        2.2        1751
# 278         1        1.3        3143
# ..        ...        ...         ...
# 211         2        3.2        3561
# 140         5        1.4        1488
# 247         2        1.7        2508
# 258         1        2.2        4924
# 97          3        3.6        1403
#
# [240 rows x 3 columns]

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.03124307,  1.55564708,  0.54329251],
#        [-1.33209074,  0.16166339,  1.46196938],
#        [-0.65042384, -1.116155  ,  0.33077527],
#        [ 1.39457688, -0.30299784, -1.11668465],
#        [-1.33209074, -1.34848562,  0.04797674],
#        [-0.65042384,  0.04549808, -0.59877847],
#        [ 0.03124307,  0.16166339,  0.60186025],
#        [ 0.03124307, -0.41916315,  0.95745011],
#        [ 0.03124307,  1.43948177,  0.170969  ],
#        [-0.65042384,  0.51015931, -0.17709072],
#        [ 0.71290997, -1.58081623,  1.18419095],
#        [ 1.39457688,  0.85865523, -1.87890198],
#        [ 1.39457688, -1.34848562, -0.90416741],
#        [-0.65042384,  1.32331647, -1.75674641],
#        [-1.33209074, -0.76765908, -0.86651672],
#        [-1.33209074,  1.09098585,  0.03877324],
#        [-1.33209074, -1.23232031,  0.98422394],
#        [ 0.03124307, -1.46465092,  0.28475776],
#        [-1.33209074,  0.393994  , -0.87488354],
#        [ 0.71290997, -1.46465092, -1.48315138],
# ...

# %%
import joblib
joblib.dump(scaler, "Scaler.pkl")
# Out:
# ['Scaler.pkl']

# %%
X_test = scaler.fit_transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = lr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 234988.62699533286

# %%
# data["Price"].describe().astype(int)
# Out:
# count       300
# mean     522761
# std      256922
# min      112666
# 25%      299936
# 50%      505806
# 75%      744603
# max      999684
# Name: Price, dtype: int32

# %%
joblib.dump(lr, "model.pkl")
# Out:
# ['model.pkl']
